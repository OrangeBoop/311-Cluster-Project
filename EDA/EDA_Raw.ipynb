# %% [markdown]
# # Library & Data import

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# %%
df = pd.read_csv('..\Data\\311_2025_Jan_Dec.csv', low_memory=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Idan\AppData\Local\Temp\ipykernel_26048\3111743989.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('..\Data\\311_2025_Jan_Dec.csv', low_memory=False)

# %%
pd.set_option('display.max_rows', 200)  # In case rows are being cut off too

# %% [markdown]
# # First look at the data

# %%
# Dataset shape
print("There are {} rows and {} columns in the dataset".format(df.shape[0], df.shape[1]))
# Out:
# There are 3645995 rows and 44 columns in the dataset

# %%
# Quick look into the first 5 rows of the dataset
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    67335722  12/31/2025 12:30:26 AM  12/31/2025 02:44:50 AM   NYPD
# 1    67347313  12/31/2025 12:30:19 AM  01/02/2026 05:18:55 PM    HPD
# 2    67352054  12/31/2025 12:30:06 AM  01/02/2026 10:07:10 AM    HPD
# 3    67348526  12/31/2025 12:30:05 AM  01/02/2026 01:49:56 PM    HPD
# 4    67348865  12/31/2025 12:30:00 AM  12/31/2025 07:32:00 AM   DSNY
#
#                                          Agency Name  \
# 0                    New York City Police Department
# 1  Department of Housing Preservation and Develop...
# 2  Department of Housing Preservation and Develop...
# 3  Department of Housing Preservation and Develop...
# 4                           Department of Sanitation
#
#   Problem (formerly Complaint Type) Problem Detail (formerly Descriptor)  \
# 0                  Blocked Driveway                            No Access
# 1                    HEAT/HOT WATER                      ENTIRE BUILDING
# ...

# %%
# See each column and its data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3645995 entries, 0 to 3645994
# Data columns (total 44 columns):
#  #   Column                                Dtype
# ---  ------                                -----
#  0   Unique Key                            int64
#  1   Created Date                          object
#  2   Closed Date                           object
#  3   Agency                                object
#  4   Agency Name                           object
#  5   Problem (formerly Complaint Type)     object
#  6   Problem Detail (formerly Descriptor)  object
#  7   Additional Details                    object
#  8   Location Type                         object
#  9   Incident Zip                          object
#  10  Incident Address                      object
#  11  Street Name                           object
#  12  Cross Street 1                        object
#  13  Cross Street 2                        object
#  14  Intersection Street 1                 object
# ...

# %%
# Lets see the problems people complain about
print(df["Problem (formerly Complaint Type)"].unique())
# Out:
# ['Blocked Driveway' 'HEAT/HOT WATER' 'Derelict Vehicles'
#  'Noise - Commercial' 'Dumpster Complaint' 'Illegal Parking'
#  'Noise - Residential' 'Noise' 'Abandoned Vehicle' 'Sidewalk Condition'
#  'Non-Emergency Police Matter' 'Street Light Condition'
#  'Indoor Air Quality' 'PLUMBING' 'FLOORING/STAIRS' 'UNSANITARY CONDITION'
#  'GENERAL' 'ELECTRIC' 'Noise - Street/Sidewalk'
#  'Special Projects Inspection Team (SPIT)' 'Lost Property' 'Elevator'
#  'Street Condition' 'Dead/Dying Tree' 'Illegal Posting' 'Dirty Condition'
#  'Food Establishment' 'Root/Sewer/Sidewalk Condition'
#  'Traffic Signal Condition' 'DOOR/WINDOW' 'Food Poisoning' 'Building/Use'
#  'WATER LEAK' 'Water System' 'APPLIANCE' 'Noise - Vehicle'
#  'Sanitation Worker or Vehicle Complaint' 'Hazardous Materials'
#  'Emergency Response Team (ERT)' 'Vendor Enforcement' 'Boilers'
#  'Taxi Complaint' 'Highway Condition' 'Drug Activity' 'Water Conservation'
#  'Consumer Complaint' 'Dead Animal' 'General Construction/Plumbing'
# ...

# %%
df["Problem (formerly Complaint Type)"].value_counts()
# Out:
# Problem (formerly Complaint Type)
# Illegal Parking                            575885
# Noise - Residential                        462195
# HEAT/HOT WATER                             314030
# Noise - Street/Sidewalk                    172808
# Blocked Driveway                           172207
# UNSANITARY CONDITION                       117519
# Water System                                77304
# Street Condition                            70169
# PLUMBING                                    69344
# Abandoned Vehicle                           67791
# Noise - Commercial                          63831
# Dirty Condition                             60913
# PAINT/PLASTER                               59126
# Noise                                       55621
# Encampment                                  47921
# Traffic Signal Condition                    47893
# DOOR/WINDOW                                 45351
# Derelict Vehicles                           43152
# ...

# %%
# Check if there are duplicates
print( df.duplicated().sum() )
# Out:
# 0

# %% [markdown]
# Well, we have 191 types of complaint... We would probably need to group same type of complaints into one category.

# %% [markdown]
# # Missing Values

# %%
# Number of missing value for each feature.
df.isnull().sum()
# Out:
# Unique Key                                    0
# Created Date                                  0
# Closed Date                               72269
# Agency                                        0
# Agency Name                                   0
# Problem (formerly Complaint Type)             0
# Problem Detail (formerly Descriptor)      84032
# Additional Details                      2256324
# Location Type                            429725
# Incident Zip                              29813
# Incident Address                         122711
# Street Name                              122820
# Cross Street 1                          1021987
# Cross Street 2                          1021119
# Intersection Street 1                   1159372
# Intersection Street 2                   1157626
# Address Type                              14303
# City                                     155664
# Landmark                                1404711
# Facility Type                           3634235
# ...

# %%
# Percentage of missing values for each feature.
df.isnull().mean()*100
# Out:
# Unique Key                               0.000000
# Created Date                             0.000000
# Closed Date                              1.982148
# Agency                                   0.000000
# Agency Name                              0.000000
# Problem (formerly Complaint Type)        0.000000
# Problem Detail (formerly Descriptor)     2.304776
# Additional Details                      61.885000
# Location Type                           11.786220
# Incident Zip                             0.817692
# Incident Address                         3.365638
# Street Name                              3.368628
# Cross Street 1                          28.030400
# Cross Street 2                          28.006594
# Intersection Street 1                   31.798508
# Intersection Street 2                   31.750620
# Address Type                             0.392293
# City                                     4.269452
# Landmark                                38.527508
# ...

# %% [markdown]
# This is the data which is Null/None/NaN... But what if the missing data was written as Unknown or Unavailable? Let's check

# %% [markdown]
# As we can see, most of the columns have missing values. We will decide on how to deal with them later on.
